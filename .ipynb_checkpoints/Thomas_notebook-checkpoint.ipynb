# %% [markdown]
# # Sarter Notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Reading Data

# %%
# read train data
df_orders = pd.read_csv("Datasets/orders.csv", sep=";")
df_products = pd.read_csv("Datasets/product_attributes.csv", sep=",")
df_dists = pd.read_csv("Datasets/cities_data.csv", sep=";")
df_ordersXproducts = pd.read_csv('Datasets/ordersXproducts.csv')
del df_ordersXproducts['Unnamed: 0']

# read test data
df_test = pd.read_csv("Altres/test.csv", sep=";")

# %%
df_dists
# Out:
#     city_from_name city_to_name          city_from_coord  \
# 0       Dusseldorf     Zaragoza  (51.2254018, 6.7763137)
# 1       Dusseldorf        Venlo  (51.2254018, 6.7763137)
# 2       Dusseldorf   Bratislava  (51.2254018, 6.7763137)
# 3       Dusseldorf      Hamburg  (51.2254018, 6.7763137)
# 4       Dusseldorf         Rome  (51.2254018, 6.7763137)
# ..             ...          ...                      ...
# 661      Rotterdam     Helsinki    (51.9244424, 4.47775)
# 662      Rotterdam       Prague    (51.9244424, 4.47775)
# 663      Rotterdam     Valencia    (51.9244424, 4.47775)
# 664      Rotterdam       Bremen    (51.9244424, 4.47775)
# 665      Rotterdam        Porto    (51.9244424, 4.47775)
#
#                          city_to_coord   distance
# 0             (41.6521342, -0.8809428)  1214.4772
# 1    (51.39244885, 6.1511724144122955)    47.3876
# 2             (48.1516988, 17.1093063)   819.2894
# 3               (53.550341, 10.000654)   339.2215
# 4             (41.8933203, 12.4829321)  1125.0290
# ..                                 ...        ...
# 661           (60.1674881, 24.9427473)  1560.6484
# 662           (50.0874654, 14.4212535)   726.5575
# 663           (39.4697065, -0.3763353)  1434.1499
# 664            (53.0758196, 8.8071646)   320.6459
# 665           (41.1494512, -8.6107884)  1558.0329
#
# [666 rows x 5 columns]

# %% [markdown]
# ## Merge tables

# %%
df_orders.join(df_products.set_index('product_id'), on='product_id').to_csv('Datasets/ordersXproducts.csv')

# %%
df = pd.merge(df_ordersXproducts, df_dists, how='left', left_on=['origin_port', 'logistic_hub'], right_on=['city_from_name', 'city_to_name'])

# %%
del df['city_from_name']
del df['city_to_name']
df = df.rename(columns={'city_from_coord': 'origin_port_coord', 'city_to_coord': 'logistic_hub_coord', 'distance': 'dist_origin_hub'})

# %%
df = pd.merge(df, df_dists, how='left', left_on=['logistic_hub', 'customer'], right_on=['city_from_name', 'city_to_name'])

# %%
del df['city_from_name']
del df['city_to_name']
del df['city_from_coord']
df = df.rename(columns={'city_to_coord': 'customer_coord', 'distance': 'dist_hub_customer'})

# %%
df = pd.merge(df, df_dists, how='left', left_on=['origin_port', 'customer'], right_on=['city_from_name', 'city_to_name'])

# %%
del df['city_from_name']
del df['city_to_name']
del df['city_from_coord']
del df['city_to_coord']
df = df.rename(columns={'distance': 'dist_origin_customer'})

# %%
df
# Out:
#             order_id origin_port    3pl customs_procedures logistic_hub  \
# 0       366c7a3d298f   Rotterdam  v_002                DTP        Venlo
# 1       45f906331e10   Rotterdam  v_004                CRF         Rome
# 2       ac84a6e4af0f      Athens  v_002                CRF        Venlo
# 3       f5e98cb29790   Rotterdam  v_004                CRF        Lille
# 4       a9e7c9bee35b   Barcelona  v_002                CRF        Venlo
# ...              ...         ...    ...                ...          ...
# 114271  3f4b15fb770e   Rotterdam  v_002                CRF   Dusseldorf
# 114272  d2e6978a38fd   Barcelona  v_004                DTD   Dusseldorf
# 114273  b88babd5c7bd   Rotterdam  v_002                DTP   Dusseldorf
# 114274  b0b5c761613f   Barcelona  v_003                DTD   Dusseldorf
# 114275  1ab8e51519e4   Rotterdam  v_002                DTD        Venlo
#
#          customer  product_id  units  late_order  weight  material_handling  \
# 0       Marseille     1692723    583        True  1778.0                5.0
# 1       Marseille     1644308    459       False  1088.0                3.0
# 2           Paris     1684170    464        True   505.0                4.0
# 3           Milan     1620510    678       False  1308.0                4.0
# 4          Berlin     1699372    353       False  1465.0                0.0
# ...           ...         ...    ...         ...     ...                ...
# 114271   Bordeaux     1681376    645       False  1896.0                3.0
# 114272     Berlin     1676942    502       False   746.0                1.0
# 114273       Rome     1692737    464       False   572.0                5.0
# 114274     Munich     1699974    388       False  1894.0                1.0
# 114275  Bucharest     1620510    482       False  1308.0                4.0
#
#             origin_port_coord                 logistic_hub_coord  \
# 0       (51.9244424, 4.47775)  (51.39244885, 6.1511724144122955)
# 1       (51.9244424, 4.47775)           (41.8933203, 12.4829321)
# 2                         NaN                                NaN
# 3       (51.9244424, 4.47775)            (50.6365654, 3.0635282)
# 4                         NaN                                NaN
# ...                       ...                                ...
# 114271  (51.9244424, 4.47775)            (51.2254018, 6.7763137)
# 114272                    NaN                                NaN
# 114273  (51.9244424, 4.47775)            (51.2254018, 6.7763137)
# 114274                    NaN                                NaN
# 114275  (51.9244424, 4.47775)  (51.39244885, 6.1511724144122955)
#
#         dist_origin_hub                    customer_coord  dist_hub_customer  \
# 0              130.0459           (43.2961743, 5.3699525)           902.0420
# 1             1269.2365           (43.2961743, 5.3699525)           604.0216
# 2                   NaN  (48.8588897, 2.3200410217200766)           392.9249
# 3              173.9644           (45.4641943, 9.1896346)           733.8784
# 4                   NaN          (52.5170365, 13.3888599)           512.8188
# ...                 ...                               ...                ...
# 114271         177.3075           (44.841225, -0.5800364)           896.2065
# 114272              NaN          (52.5170365, 13.3888599)           477.3717
# 114273         177.3075          (41.8933203, 12.4829321)          1125.0290
# 114274              NaN          (48.1371079, 11.5753822)           487.5926
# 114275         130.0459          (44.4361414, 26.1027202)          1672.4754
#
#         dist_origin_customer
# 0                   961.6350
# 1                   961.6350
# 2                        NaN
# 3                   797.3505
# 4                        NaN
# ...                      ...
# 114271              871.6731
# 114272                   NaN
# 114273             1269.2365
# 114274                   NaN
# 114275             1801.3393
#
# [114276 rows x 17 columns]

# %%
s = 0
for i in range(len(df)):
    if (isinstance((df.at[i, 'logistic_hub']), str)):
        s += 1
        
print(s)
# Out:
# 63336

# %% [markdown]
# # Insights

# %%
df = pd.read_csv('Datasets/ordersXproducts.csv')
del df['Unnamed: 0']

# %%
df
# Out:
#             order_id origin_port    3pl customs_procedures logistic_hub  \
# 0       366c7a3d298f   Rotterdam  v_002                DTP        Venlo
# 1       45f906331e10   Rotterdam  v_004                CRF         Rome
# 2       ac84a6e4af0f      Athens  v_002                CRF        Venlo
# 3       f5e98cb29790   Rotterdam  v_004                CRF        Lille
# 4       a9e7c9bee35b   Barcelona  v_002                CRF        Venlo
# ...              ...         ...    ...                ...          ...
# 114271  3f4b15fb770e   Rotterdam  v_002                CRF   Dusseldorf
# 114272  d2e6978a38fd   Barcelona  v_004                DTD   Dusseldorf
# 114273  b88babd5c7bd   Rotterdam  v_002                DTP   Dusseldorf
# 114274  b0b5c761613f   Barcelona  v_003                DTD   Dusseldorf
# 114275  1ab8e51519e4   Rotterdam  v_002                DTD        Venlo
#
#          customer  product_id  units  late_order  weight  material_handling
# 0       Marseille     1692723    583        True  1778.0                5.0
# 1       Marseille     1644308    459       False  1088.0                3.0
# 2           Paris     1684170    464        True   505.0                4.0
# 3           Milan     1620510    678       False  1308.0                4.0
# 4          Berlin     1699372    353       False  1465.0                0.0
# ...           ...         ...    ...         ...     ...                ...
# 114271   Bordeaux     1681376    645       False  1896.0                3.0
# 114272     Berlin     1676942    502       False   746.0                1.0
# 114273       Rome     1692737    464       False   572.0                5.0
# 114274     Munich     1699974    388       False  1894.0                1.0
# 114275  Bucharest     1620510    482       False  1308.0                4.0
#
# [114276 rows x 11 columns]

# %%
counts = df['late_order'].groupby(df['units']).value_counts()

# %%
type(counts)
# Out:
# pandas.core.series.Series

# %%
for i in range(1, 952):
   print(i, ":", counts[i][0]/(counts[i][0]+counts[i][1]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-171-c839895ff64b> in <module>
#       1 for i in range(1, 952):
# ----> 2    print(i, ":", counts[i][0]/(counts[i][0]+counts[i][1]))
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     851
#     852         elif key_is_scalar:
# --> 853             return self._get_value(key)
#     854
#     855         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     959
#     960         # Similar to Index.get_value, but we do not fall back to positional
# --> 961         loc = self.index.get_loc(label)
#     962         return self.index._get_values_for_loc(self, loc, label)
#     963
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 0
